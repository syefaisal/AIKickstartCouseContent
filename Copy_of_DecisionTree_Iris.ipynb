# %% [markdown]
# <a href="https://colab.research.google.com/github/syefaisal/AIKickstartCouseContent/blob/main/Copy_of_DecisionTree_Iris.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Importing necessary modules & dataset

# %%
# Importing necessary libraries
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier,plot_tree
from sklearn.metrics import accuracy_score

# %% [markdown]
# Loading the dataset and splitting it into train and test portions

# %%
# Load the Iris dataset
iris = load_iris()
X = iris.data  # Features
y = iris.target  # Target variable

# Split the dataset into training and testing sets (80% train, 20% test)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=23)

# %% [markdown]
# Intialize a Decision tree classifier and fit the Training Data

# %%
# Initialize the Decision Tree Classifier
clf = DecisionTreeClassifier()

# Train the Decision Tree Classifier
clf.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %% [markdown]
# Make predictions with your Trained Model using the test Portion and check for accuracy

# %%
# Make predictions on the test set
y_pred = clf.predict(X_test)

# Calculate accuracy
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.9736842105263158

# %% [markdown]
# Let's get a Visual of the decision tree

# %%
#Import the necessary Library
import matplotlib.pyplot as plt
#Plot the decision tree
plt.figure(figsize=(15, 15))
plot_tree(clf, filled=True, feature_names=iris.feature_names, class_names=iris.target_names)
plt.show()

# %%
clf2 = DecisionTreeClassifier(criterion='entropy')

# Train the Decision Tree Classifier
clf2.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy')

# %%
# Make predictions on the test set
y_pred = clf2.predict(X_test)

# Calculate accuracy
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.9736842105263158

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
# Print confusion matrix
cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, cmap="Blues", fmt="d", xticklabels=iris.target_names, yticklabels=iris.target_names)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()
